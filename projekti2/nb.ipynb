# %%
import kagglehub
import warnings
warnings.filterwarnings("ignore")

# Download latest version
path = kagglehub.dataset_download("shravankumar9892/image-colorization")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/shravankumar9892/image-colorization?dataset_version_number=4...
#   1%|          | 15.0M/2.10G [00:15<37:34, 995kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 warnings.filterwarnings("ignore")
#       6 # Download latest version
# ----> 7 path = kagglehub.dataset_download("shravankumar9892/image-colorization")
#       9 print("Path to dataset files:", path)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\kagglehub\datasets.py:28, in dataset_download(handle, path, force_download)
#      26 h = parse_dataset_handle(handle)
#      27 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 28 return registry.dataset_resolver(h, path, force_download=force_download)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\kagglehub\registry.py:23, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      21 for impl in reversed(self._impls):
#      22     if impl.is_supported(*args, **kwargs):
# ---> 23         return impl(*args, **kwargs)
#      24     else:
#      25         fails.append(type(impl).__name__)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\kagglehub\http_resolver.py:125, in DatasetHttpResolver.__call__(self, h, path, force_download)
#     122 os.makedirs(os.path.dirname(archive_path), exist_ok=True)
#     124 # First, we download the archive.
# --> 125 api_client.download_file(url_path, archive_path, h)
#     127 # Create the directory to extract the archive to.
#     128 os.makedirs(out_path, exist_ok=True)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\kagglehub\clients.py:191, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path)
#     189 else:
#     190     logger.info(f"Downloading from {url}...")
# --> 191     _download_file(response, out_file, size_read, total_size, hash_object)
#     193 if hash_object:
#     194     actual_md5_hash = to_b64_digest(hash_object)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\kagglehub\clients.py:231, in _download_file(response, out_file, size_read, total_size, hash_object)
#     229 with tqdm(total=total_size, initial=size_read, unit="B", unit_scale=True, unit_divisor=1024) as progress_bar:
#     230     with open(out_file, open_mode) as f:
# --> 231         for chunk in response.iter_content(CHUNK_SIZE):
#     232             f.write(chunk)
#     233             if hash_object:
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\urllib3\response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\urllib3\response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\urllib3\response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\site-packages\urllib3\response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\http\client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\ebe22\anaconda3\envs\nvidiaGPU\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
